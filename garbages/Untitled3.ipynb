# %%
# %matplotlib inline 
import numpy as np 
import matplotlib.pyplot as plt 

x = np.load('test_x.npy')
y = np.load('test_y.npy')

print (np.mean(x), np.mean(y))
print (np.max(x), np.max(y))

# x = (x > np.mean(x) * 3).astype(np.float)
# y = (y > 100).astype(np.float)
# y[y < 100] = 0

fig=plt.figure(figsize=(18, 18))
plt.subplot(121)
plt.imshow(x, cmap='gray')
plt.subplot(122)
plt.imshow(y, cmap='gray')
plt.show()
# Out:
# 6443.708372622728 1769.5729937814176
# 10024.1298828125 776036.375
