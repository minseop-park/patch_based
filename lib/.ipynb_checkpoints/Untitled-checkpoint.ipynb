# %%
from dataset import get_train_pair
import numpy as np

x, y = get_train_pair(10)

print (np.mean(y), np.max(y), np.min(y))
print (np.mean(x), np.max(x), np.min(x))
# Out:
# 1.1345026302337633 126.22500000000014 0.0
# 248.78319931030273 3016 -2000

# %%
import matplotlib.pyplot as plt

x, y = get_train_pair(10)
# y = np.exp(y)
print (np.mean(y), np.max(y), np.min(y))

for i in range(10):
    img = (y[i] > 14) * y[i]

    plt.imshow(img, cmap='gray')
    plt.show()
# Out:
# 1.168173809051511 132.5999999999999 0.0
