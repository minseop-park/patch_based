# %%
# %matplotlib inline
from dataset import get_train_pair
import numpy as np

x, y = get_train_pair(10)

print (np.mean(y), np.max(y), np.min(y))
print (np.mean(x), np.max(x), np.min(x))
# Out:
# 1.127310132980345 122.40000000000009 0.0
# 214.1766227722168 3197 -2000

# %%
import matplotlib.pyplot as plt

x, y = get_train_pair(10)
# y = np.exp(y)
print (np.mean(y), np.max(y), np.min(y))

for i in range(10):
#     img = (y[i] > 14) * y[i]
    img = y[i] / 10

    plt.imshow(img, cmap='gray')
    plt.show()
# Out:
# 1.0498536300659154 124.95000000000005 0.0
